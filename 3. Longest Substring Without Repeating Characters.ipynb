# %%
a = "sednzdmcmrydnbulqvktvutsqizewmboqedrjqtvjuayxujnswhpqchgm"
b = []
str_content = []
if a:
    length = 1
else:
    length = 0
for i in a:
    b.append(i)
    print(b)
    print(set(b))
    if len(b) != len(set(b)):
        index = b.index(i)
        if length < len(b) - 1:
            length = len(b) - 1
            str_content = ''.join(b[0:-1])

        b = b[index + 1:]
#         print(set(b))
    else:
        if len(b)>= length:
            length = len(b)
            str_content = ''.join(b)
        
    print(str_content)
print(length)
print(str_content)
# print(a)
# Out:
# ['s']
# {'s'}
# s
# ['s', 'e']
# {'s', 'e'}
# se
# ['s', 'e', 'd']
# {'s', 'e', 'd'}
# sed
# ['s', 'e', 'd', 'n']
# {'s', 'e', 'n', 'd'}
# sedn
# ['s', 'e', 'd', 'n', 'z']
# {'e', 's', 'd', 'n', 'z'}
# sednz
# ['s', 'e', 'd', 'n', 'z', 'd']
# {'e', 's', 'd', 'n', 'z'}
# sednz
# ['n', 'z', 'd', 'm']
# {'m', 'n', 'z', 'd'}
# sednz
# ['n', 'z', 'd', 'm', 'c']
# {'d', 'm', 'c', 'n', 'z'}
# nzdmc
# ['n', 'z', 'd', 'm', 'c', 'm']
# {'d', 'm', 'c', 'n', 'z'}
# nzdmc
# ['c', 'm', 'r']
# {'m', 'c', 'r'}
# nzdmc
# ['c', 'm', 'r', 'y']
# {'y', 'm', 'c', 'r'}
# nzdmc
# ['c', 'm', 'r', 'y', 'd']
# {'y', 'd', 'm', 'c', 'r'}
# cmryd
# ['c', 'm', 'r', 'y', 'd', 'n']
# {'y', 'd', 'm', 'c', 'r', 'n'}
# cmrydn
# ['c', 'm', 'r', 'y', 'd', 'n', 'b']
# {'y', 'd', 'm', 'c', 'r', 'n', 'b'}
# cmrydnb
# ['c', 'm', 'r', 'y', 'd', 'n', 'b', 'u']
# {'y', 'd', 'm', 'c', 'r', 'n', 'b', 'u'}
# cmrydnbu
# ['c', 'm', 'r', 'y', 'd', 'n', 'b', 'u', 'l']
# {'y', 'l', 'd', 'm', 'c', 'r', 'n', 'b', 'u'}
# cmrydnbul
# ...

# %%
a = 'abcabcbb'
b = []
length = 0
for i in a:
    b.append(i)
    print(b)
    print(set(b))
# Out:
# ['a']
# {'a'}
# ['a', 'b']
# {'b', 'a'}
# ['a', 'b', 'c']
# {'b', 'a', 'c'}
# ['a', 'b', 'c', 'a']
# {'b', 'a', 'c'}
# ['a', 'b', 'c', 'a', 'b']
# {'b', 'a', 'c'}
# ['a', 'b', 'c', 'a', 'b', 'c']
# {'b', 'a', 'c'}
# ['a', 'b', 'c', 'a', 'b', 'c', 'b']
# {'b', 'a', 'c'}
# ['a', 'b', 'c', 'a', 'b', 'c', 'b', 'b']
# {'b', 'a', 'c'}

# %%
d = [ 'a', 'b', 'c', 'a']
num = d.index('a')

# %%
for nu in num:
    print(nu)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-ec124fe2a5b3> in <module>()
# ----> 1 for nu in num:
#       2     print(nu)
#
# TypeError: 'int' object is not iterable

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-adb21195ff2a> in <module>()
# ----> 1 num[1]
#
# IndexError: string index out of range
